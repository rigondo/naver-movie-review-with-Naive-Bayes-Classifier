# %% [markdown]
# # 기말고사 대체과제
# ## 201400518 박찬형

# %%
import pandas as pd
import numpy as np

import requests # 예전에 했었던 request를 임포트해서 사용
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib
from urllib import parse
import time
from IPython.display import Image

# %%
 Image("지능정보 스샷.png")

# %%
 Image("지능정보 스샷2.png")

# %% [markdown]
# ## 요청(request)을 보내면 응답(response)을 받는다. 당연히 이 응답은 python 객체로 받는다. 그리고 이 응답 객체는 많은 정보와 기능을 가지고 있다.
#
# ### res.request # 내가 보낸 request 객체에 접근 가능
# ### res.status_code # 응답 코드

# %%
base_url = 'https://movie.naver.com/movie/point/af/list.nhn?&page={}'
url = base_url.format(1)
res=requests.get(url)

if res.status_code == 100: ## 응답코드
    soup = BeautifulSoup(res.text) ## res.txt로 수프에 넣어줌
    tds = soup.select('table.list_netizen > tbody > tr > td.title')# 웹보면 직계자식 > 이걸 사용해 편함
    print(len(tds))
    for td in tds:
        movie_title = td.select_one('a.movie').text.strip()
        score = td.select_one('div.list_netizen_score > em').text.strip()
        comment = td.select_one('br').next_sibling.strip()
        print(movie_title, score, comment, sep=' : ')

# %%
from tqdm.notebook import tqdm

tmp_list = []
 
for i in tqdm(range(1, 30)):
    url = 'https://movie.naver.com/movie/point/af/list.nhn?&page='+str(i)
    res=requests.get(url)
    soup = BeautifulSoup(res.text)
    tds = soup.select('table.list_netizen > tbody > tr > td.title')
    
    for td in tds:
        movie_title = td.select_one('a.movie').text.strip()
        score = td.select_one('div.list_netizen_score > em').text.strip()
        comment = td.select_one('br').next_sibling.strip()
        if(int(score) > int(8)): # 전부 int 형으로 바꿔서 9점 10점 평점만이 워드클라우드에 포함시킴.
            print(movie_title, comment, sep=' : ')
            tmp_list.append(comment)
    
    time.sleep(0.5)
print(len(tmp_list))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))
# C:\Users\admin\anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\admin\anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 악인전 :
# 콜 : 기대감 없이 본 영화지만 반전과 신선함을 준 영화이다.전 배우들의 연기력은 물론이며,전종서 배우님의 연기력은 정말 대단했습니다.영상연출도 좋았지만 영상 ost도 아주 좋았습니다.또한 스토리 자체도 타임라인을 다룸과 동시에반사회적 인격장애를 풀어낸 것이 아주 인상깊었습니다.
# 녹터널 애니멀스 :
# 콜 : 연기, 연출 모두 훌륭해요
# 가을의 전설 : 몇번을 봐도 여운이 남는 영화.
# 콜 : 코로나 시대가 아니라면 1500만 갔을 영화입니다두젊은 여배우님의 연기가 압권입니다.
# 콜 : 마지막으로 영화 본게 살아있다인데 너무 재밌네요. 반전에 반전에 반전에 반전 와이프랑 술 한 잔하고도 엄청 몰입하고 봤습니다.
# 롱 리브 더 킹: 목포 영웅 : ㅎㅎ너무재밌게봤어요!!!
# 우아한 세계 : 이 시대 아버지의 모습 그대로네요.
# 리클레임 : 재미있고 부모로서 긴장감 있게 봣음. 좋은 영화임 스토리 엉성해 보이지만 그래더 긴장감 웬만한 약션영화보다 좋음 아마추어성 느낌이 나지만 그래서 약가누더ㅜ실화 같은 느낌.
#
# 185

# %%
from konlpy.tag import Okt #수업 때 사용한 Okt 그대로 씀
okt = Okt()

# %%
ko_doc = '\n'.join(tmp_list)
print(ko_doc[:1000])
# Out:
# 기대감 없이 본 영화지만 반전과 신선함을 준 영화이다.전 배우들의 연기력은 물론이며,전종서 배우님의 연기력은 정말 대단했습니다.영상연출도 좋았지만 영상 ost도 아주 좋았습니다.또한 스토리 자체도 타임라인을 다룸과 동시에반사회적 인격장애를 풀어낸 것이 아주 인상깊었습니다.
#
# 연기, 연출 모두 훌륭해요
# 몇번을 봐도 여운이 남는 영화.
# 코로나 시대가 아니라면 1500만 갔을 영화입니다두젊은 여배우님의 연기가 압권입니다.
# 마지막으로 영화 본게 살아있다인데 너무 재밌네요. 반전에 반전에 반전에 반전 와이프랑 술 한 잔하고도 엄청 몰입하고 봤습니다.
# ㅎㅎ너무재밌게봤어요!!!
# 이 시대 아버지의 모습 그대로네요.
# 재미있고 부모로서 긴장감 있게 봣음. 좋은 영화임 스토리 엉성해 보이지만 그래더 긴장감 웬만한 약션영화보다 좋음 아마추어성 느낌이 나지만 그래서 약가누더ㅜ실화 같은 느낌.
# 연기력,영상미, 연출, 배경음악 몰입도  네요빗나간 인간의 집착이 무모하고, 고뇌하는인간의처절한삶을 잘 묘사한듯 합니다. 아름다운영상이었어요...
# 전종서님 연기 진짜잘하신다..소름돋네 이분나오는거다봐야겠다배우들전체적으로 연기 다 너무잘하고어색한거하나 없음 스토리도 너무좋아시그널같아..
# 와 내용도 내용이지만 박혜수??
# 정우 오달수 너무 좋았다 진짜
#
# 전종서 다 내려놨네.. 연기 개쩜
# 너무 무서워서 끊어가며 겨우 봤네요;; 박신혜 전종서 두 배우 연기 매우 좋고 연출 스토리 모두 잘 짜여져 있네요 왜 영화관에서 개봉 안했는지 모르겠어요 전종서 배우 싸이코패스 연기 넘 잘하네요 앞으로가 기대되요^^
# 감동입니다 보시는거 추천해요
# 정말 살고싶게 만드는 영화
# 버닝때부터 알아봣음 전종서 연기 개자람
# 미쳤어.... 전종서가 ㅈㄴ 무서운데 왜케 연기가 멋있어..
#
# 와..진짜 최근본영화중 최고..코로나때메ㅠㅠ
# 와 진짜 대박...숨을 못 쉬겠어이불없이는 못봐
# 넷플릭스에서 개봉한게 너무 아깝다ㅠㅠ
# 프리퀀시가 생각나는 영화. 그렇지만 색다르게 잘 풀어냈다고 봄.
# 그냥 아무생각 없이 봤는데 몰입도 매우 뛰어나고요. 연

# %%
print(len(ko_doc))
# Out:
# 8478

# %%
import time

start = time.time()
ko_doc_noun = okt.nouns(ko_doc)
print(time.time()-start)
# Out:
# 4.972240924835205

# %%
from collections import Counter

count_noun = Counter(ko_doc_noun)

# %%
count_noun.most_common(20) # 가장 많이 반복된 것들 20개 순위
# Out:
# [('영화', 84),
#  ('연기', 46),
#  ('전종', 34),
#  ('진짜', 34),
#  ('배우', 25),
#  ('이', 16),
#  ('생각', 16),
#  ('스토리', 15),
#  ('최고', 14),
#  ('연출', 13),
#  ('때', 12),
#  ('반전', 10),
#  ('정말', 10),
#  ('것', 10),
#  ('몰입도', 10),
#  ('스릴러', 10),
#  ('만', 10),
#  ('다시', 10),
#  ('그', 10),
#  ('연기력', 9)]

# %%
stopword_list = ['영화', '연기', '배우','전종','진짜'] # 5개 반복된것들 제거함

for word in count_noun:
    if len(word) == 1:
        stopword_list.append(word)
        
stopword_list[-5:]
# Out:
# ['알', '향', '쩜', '곳', '또']

# %%
# stopword 단어를 모두 pop()

for stopword in stopword_list:
    if stopword in count_noun:
        count_noun.pop(stopword)

# %%
from wordcloud import WordCloud

# mac OS: '/Library/Fonts/NanumBarunGothic.ttf'
wc_noun = WordCloud(background_color='white', max_words=2000, 
                     font_path=r'C:\Windows\Fonts\NanumGothic.ttf')
wc_noun = wc_noun.generate_from_frequencies(count_noun)

import matplotlib.pyplot as plt
plt.imshow(wc_noun, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import numpy as np
from PIL import Image

img_mask = np.array(Image.open('way.png')) # 화살표 이미지 입히기

wc_img = WordCloud(background_color='white', max_words=5000, font_path=r'C:\Windows\Fonts\NanumGothic.ttf',
                  mask=img_mask)

wc_img = wc_img.generate_from_frequencies(count_noun)

import matplotlib.pyplot as plt
plt.imshow(wc_img, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # (Naïve Bayes Classifier) 학습 시키기
# ## 위에는 9~10점만 텍스트 가져왔었음!
# ### 이제는 점수별로 텍스트 가져올것

# %%
from tqdm.notebook import tqdm

tmp_list = []
txt_list = []
 
for i in tqdm(range(1, 50)):
    url = 'https://movie.naver.com/movie/point/af/list.nhn?&page='+str(i)
    res=requests.get(url)
    soup = BeautifulSoup(res.text)
    tds = soup.select('table.list_netizen > tbody > tr > td.title')
    
    for td in tds:
        movie_title = td.select_one('a.movie').text.strip()
        score = td.select_one('div.list_netizen_score > em').text.strip()
        comment = td.select_one('br').next_sibling.strip()
        #if(int(score) > int(8)): # 전부 int 형으로 바꿔서 9점 10점 평점만이 워드클라우드에 포함시킴.
        print(movie_title, score, comment, sep='\t')
        txt_line = f"{movie_title}\t{score}\t{comment}\n"
        txt_list.append(txt_line)
        tmp_list.append(comment)
    
    time.sleep(0.5)        
print(len(tmp_list))

# 출력 결과들을 train.txt 파일로 저장을 시킴
try:    
    f = open("train.txt",'w','utf-8')
    for txt in txt_list:
        f.write(txt)
except Exception as e:
    print(e)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=49.0), HTML(value='')))
# C:\Users\admin\anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\admin\anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 이웃사촌	9	도청팀이랑 여수댁 너무 웃겨요ㅋㅋㅋ
# 악인전	10
# 이별의 아침에 약속의 꽃을 장식하자	6	힘없는 불멸의 삶은 고통.
# 콜	9	기대감 없이 본 영화지만 반전과 신선함을 준 영화이다.전 배우들의 연기력은 물론이며,전종서 배우님의 연기력은 정말 대단했습니다.영상연출도 좋았지만 영상 ost도 아주 좋았습니다.또한 스토리 자체도 타임라인을 다룸과 동시에반사회적 인격장애를 풀어낸 것이 아주 인상깊었습니다.
# 녹터널 애니멀스	10
# 백두산	2	정말 배우들이 아깝다는 생각이 ...
# 콜	10	연기, 연출 모두 훌륭해요
# 가을의 전설	8	그러게 동생 여자랑 결혼은 하지 말았어야지  그럼에도 불구하고 볼거리 많은 영화는 분명함
# 더럽혀진 얼굴의 천사	1	남자의 마지막 자존심을 굽히는것이 선이란 말인가. 거짓되고 인위적이고 위선적인 주제. 철학없는 쓰레기 방범 캠페인영화. 이런영화가 고전명작 반열에 들고있다는것이 어처구니가 없다
# 시크릿 가든	5	정원은 예뻤었지...
# 2012	10	2012년은 한참 지났지만 재난영화 중 볼만한 영화라고 생각돼요!
# 일급 살인	10	잔잔한 브로맨스, 최고의 연기,영화가 끝나고도 생각에 잠기게 만드는 명작
# 콜	9	전종수라는 배우의 발견!! 타임슬립 영화로서 새로운 전개라서 새롭고스토리도 나름 흥미진진오랫만에 재밌게본 한국 영화
# 콜	10	이제막다봤는ㄷㅔ...꿈에나올듯이 생생해요연기..와..남편이랑 같이봐서.다행이에요진짜 .. 오영숙 실제로 우리집에있을듯잘봤어요
# 콜	10	집중력 최고. 마지막까지 소름.
# 어디갔어, 버나뎃	10	버나뎃 캐릭터의 아픔이 너무 공감되어서 좋았습니다.
# 가을의 전설	10
# 콜	10	전종서 연기 진짜 미쳤습니다.
# 콜	10
# 나의 소녀시대	10	고등학교때 보고 4년만에 다시 봤는데도 눈물 ㅜㅜ 나는 왜 고등학교때 저런 사랑 못해봤을까..
# 국가부도의 날	9	imf라는 소재자체가 워낙 드라마티컬하니까 중간은 가겠지라고 생각하고 별 기대 없이 봤는데, 이렇게나 그 시기의 여러 계층과 처지의 사람들을 다층적으로 보여주면서 아픈데 찌를지 몰랐다. 잘 만든 아픈 영화네요...
# 콜	10	걍 보세요 미친 연기 보실 수 있습니다
# 더 넌	10	딱히 기대안하고봤는데 재밌어요 브금도 좋고요
# 죽지않는 인간들의 밤	3	이걸. 정말. 영화라고... 왠만하면.. 끝까지 보는데.. 이건...
# 콜	10	오 재밌네요 굿굿굿~~~~
# 종이꽃	10	이 영화를 간단히 말씀드리자면주룩~주룩~ 흘러내리는 나의 눈물이 답이다.
# 삼진그룹 영어토익반	10
# 콜	9	타임슬립 영화가 많아지다보니 스토리가 엄청 신선한 것은 아니지만, 연출과 연기에 8점 생각함.그런데 넷플이 아닌 극장에서 개봉했다면 더욱 현장감 있었을 것이라는 생각에 9점 줌.전종서라는 배우를 좋아하게 되었지만, 실제로 만나면 무서울 것 같음.
# 크리스마스에 기적을 만날 확률	8	아기납치한 여자 패죽이고 싶더라 옥상에서 개맞듯 두들겨 맞아야함
# 라이트 아웃	6	별로 무섭지 않아요 ㅎㅎ
# 아쿠아맨	10	Ost, everything i need 진짜 좋음
# 엑설런트 어드벤쳐 3	10
# 콜	10	미쳤어요 진짜!! 오랜만에 소름돋았네요!!
# 콜	10	마지막까지 심장이 쪼그라드네요.전종서씨 연기를 그렇게 하시면 ...ㅜㅜㅜㅜ
# 디파티드	10	재밌어요 평점 낮아서 올려드린
# 극장판 바이올렛 에버가든	10	바이올렛 에버가든을 보면 항상 슬퍼진단 말이죠..감정이입이 가장 잘되는 애니라고 단정지을수 있습니다!
# 콜	1	보는 내내 답답함 주인공이 너무 멍청한 영화 영화관에서 봤으면 돈아까웠을 영화내요 결말 부분에 긴장감 1도 없어서 10초 건너뛰기 오지게 했다...ㅎ
# 박하사탕	10	명작은 시간이 흐를수록 그 진가를 발휘한다.
# 이웃사촌	10	마음 따뜻해지는 감동영화 연말에 꼭 봐야할 영화
# 프리키 데스데이	1	평점보고 기뻐하면서 방금 보고옴  평점조작이 확실합니다 여지껏 본영화중 중간에 나오고싶은 충동이  최고였어요
# 콜	6	박신혜의 입을 막아 버리고 싶다 ㅡ"ㅡ
# 불한당: 나쁜 놈들의 세상	10	막상 영화가 끝나자마자 드는 생각은 별거 없었다. 아 생각보단 덜 슬프네, 영화 재밌었다 정도?이 영화의 진짜는 영화를 다 감상한 그 뒤부터 시작이다.. 밤마다 영화 생각이 문득문득 난다.
# 해피 데스데이	2	진짜...재미없어요 시간아까움 하
# 종이꽃	10	역시 안성기씨가 출연하는 영화는 대단하네요.. 잔잔한 감동.. 오랜만에 좋은 영화 봤습니다.
# 콜	10	이거 한국영화 아니다. 해외배급사라서 그런가? 관객에게 건방지게 계몽(PC주의)하려드는 그런 뻔한 한국영화들이 아니다. 오로지 연출과 스토리에만 충실하다.
# 콜	10	인터스텔라+보이스+김치갬성 전종서 연기 미쳤음
# 82년생 김지영	10
# 콜	2	시그널 아이디어 그대로인데 전개는 너무 비교됌 주인공이 너무 멍청해서 발암임
# 밀리언 달러 베이비	10	다 좋았더라면 이렇게 긴 여운이 남았을까요 내사랑 나의핏줄
# 콜	10	와 ㅋㅋ기대 안 하고 봤는데 존잼. 전종서 연기 미쳤음 엔딩 마음에 든다
# 콜	10
# 콜	8	전종서 배우의 연기가 너무 뛰어나네요.
# 프로메테우스	9	에일리언 비긴즈 엄지척
# 삼진그룹 영어토익반	6
# 최미역행	1	짱x자본 얼마나 처드셨나요?
# 얼론	1	한국영화 살아있다하고 내용이 똑같음 누가 표절을 했는지는 알수 없으나 한심한 영화입니다
# 콜	10
# 힐빌리의 노래	10	재미있게 잘 봤습니다.
# 콜	2	연기는 잘하나 OO같은 전개에 답답함은 내몫
# 콜	4	감독은 사람들이 이 영화를 보고 마지막에 무엇을 느끼게 하고 싶었나 나는 ㅈ같음을 느꼈다..
# 콜	10	간만에 대박영화 나옴. 대단한 연기.연출.긴장감.예상을 넘는 전개.
# 결정적 한방	6	결정적 한방이 부족한 영화. 정치를 그려내려했으나 이상적이고 어색하고 드라마적이다. 그래도 그부분에 +1점.
# 콜	10	전종서라는 배우로 인해 너무 영화를 재밌게봤습니다. 너무 매력적인 배우. 영화를 영화답게 만들어준 많은 스탭들중 전종서라는 배우가 유독 마음을 흔들었습니다.
# 스타 이즈 본	10	여운이 길게 남는..
# 가을의 전설	6	트리스탄이랑 엮이면 인생 피곤해지는데
# 시네마 천국	10	말이 필요 없는 인생 최고의 감독 대작!
# 콜	10	극장개봉했으면 중박이상이라생각함
# 콜	1	이런 엉성한 스토리로..  만들면 좋냐?시간적 흐름에 대하여 논리적으로 펼쳐야 납득이 가지...  참 그지같네
# 콜	10	우와 영화리뷰 절대안쓰는데 이건완전 몰입도짱! 꼭 보세요! 코로나 아니었음 정말 대박날영화 박신혜님 과 그 주인공언니 대박연기력짱
# 콜	10	2...나오는건가요?
# 삼진그룹 영어토익반	8	기대 안했는데 재밌고 꽤 볼만해여 ㅎㅎ
# 콜	10	진짜... 연기 미쳤고 시나리오 작가 미쳤다... 너무 무섭다 오늘 혼자 못잘듯 ㅠㅠ
# 콜	10	너무 무서웠어요~~ 영화관에서 봤음 더 무서웠을듯~~ 재미있게 봤어요
# 콜	8	오랜만에 신선한 작품을 봤다 다만 엔딩을 그렇게 했어야 했다면 다음편에서 그 타당성을 증명해야 할 것 같다
# 콜	6	굳이 마지막장면을 왜?
# 런	8	개꿀잼 90분 실전형 압축잼 긴장감 훌륭
# 콜	1	마지막은 차라리 안넣는게 나았을듯
# 플립	4	스토리는 좋지만 완성도 면에서 너무 떨어지네요 떡밥은 회수하자 진자
# 콜	2	오류 투성이.극장서 본게 아니어서 다행.하지만 전종서 연기는 압권.
# 콜	1	레알 관객에게 찝찝함을 선사하네 ㅋㅋ..이런 소재로 스토리를 굳이 이렇게 짤 수 밖에 없나요 ?
# 콜	10	너무 무서워서 건너뛰고싶은데 또 궁금해서 다봐버렸어여ㅠㅠ
# 콜	10	이름나오는 뒤에도 꼭 봐야함대반전이 숨겨져있음
# 최미역행	1	영화 평점이 특급 마무리 투수 방어율이네요. 0점이 없어서 아쉽습니다.
# 극장판 바이올렛 에버가든	10	살면서 영화로 이렇게 아름답고 슬프고 웃음이 나온 적은 처음이었다 밖에 나가 영화관에서 본 것은 잘못된 건 맞지만 나중에 vod로 나오면 영화관에서 본 느낌에 반절도 되지 않을 거 같다
# 블랑섹의 기이한 모험	5	이게 뭔 내용이야...
# 런	10	처음 부터 끝까지 숨 넘어갈듯해요.. 긴장감 대박.. 제대로 된 영화 봤어요
# 콜	10	너무 무서워요ㅠㅠ쉬야 마려운데  쉬야못하는중 ㄷㄷ
# 콜	10	쫄앗네 개무서워 연기지렷다전종서라는사람의 연기력이 이영화를 찢었다
# 콜	6
# 런	10	너무 너무 재미있게 봤어요
# 삼진그룹 영어토익반	10	너무 재미있어요 극장에서 못 본 게 아쉬워요
# 딥워터 호라이즌	10	진짜 재밌게 봤어요 묘사가 갠적으로 아찔해서 ㄷㄷ했지만요..ㅎ
# 프리키 데스데이	1	남주 연기 빼고 볼 거 없음스토리 개막장에 설정 자체가 너무너무 유치함;;쏘우 좋아하는 초딩이 만든 영화같음억지감동에 그냥 잔인하기만함...평점 9점대여서 기대하고 봤는데 개낚임평점 3점 이상 준 사람들 죄다 댓글 알바...공포의묘지 급
# 콜	1	같이 통화하면서 현재 과거 연결되는 부분에서 영화 끔ㅋㅋㅋㅋ진짜 이딴게.. 뭔....
# 이웃사촌	2	나는 누구 여긴 어디 중간에 나옴
# 콜	1	영화가 소재는 참신한데 스토리가 결국 용두사미네요 특히 결말이 너무 무책임해요..
# 타오르는 여인의 초상	8	'모든 게 덧없는 건 아니에요. 어떤 감정은 깊죠.' 심장이 타는 초상화의 상징. 여성 서사와 에우리디케가 '뒤돌아봐' 라고 말했다는 주체성. 19세기 말까지도 왕가와 귀족가는 초상화를 보고 결혼할 상대를 평가했다. 평단의 극찬에도 불구하고 <기생충>에 팔마도르를 뺏겼다. 다르덴 형제 감독의 <언노운 걸>에서 인상적인 연기를 선보이기도 했던 아델 에넬은 셀린 시아마 감독과 '전'연인사이다.(아마 감독 데뷔작이자 아델이 주연이던 <워터 릴리스>에서 연결됐을 것이다. 이 영화가 세 번째 함께 한 작품.)
# 콜	9	전종서 연기 왜케 잘함마지막에 나름 반전도 있고간만에 흥미진진한 스릴러 봤네요재밌습니다 강추하는 스릴러물
# 언힌지드	10	러셀크로우의 시원시원한 액션에 스트레스가뻥뚫리는 영화
# 콜	10
# 콜	2	마지막 ㄹㅇ 말이안됨 ㅋㅋㅋ 어줍짢은 반전 기획한것 같은데 디시 생각해봐도 말이안됨. 안넣는게 차라리 낳았음 ㅋ
# 콜	10	오랜만에 영화다운 영화봤다
# 극장판 바이올렛 에버가든	10	부천 애니메이션 시작으로 10번째 감상중 볼때마다 좋음 이번주 특전까지 가면 12번째 ㅋㅋ 넘 좋아
# 도굴	10	생각보다 잼씀 주변에서 재미없댔는데
# 테넷	10	좋을듯좋은듯졸은듯한 영화
# 클라우스	9	혐오와 폭력으로 얼룩진 세상에 사랑을 전파했던 인간 클라우스의 이야기.요즘같은 세상에 더 와닿는다. 크리스마스 뿐만 아니라 365일 사랑이 가득하길..
# 스타 이즈 본	10	ost 너무좋아요!앤딩만 4번돌려봤네요오랜만에 펑펑울었답니다ㅜ
# 콜	10	어떻게 보느냐에 따라 호불호 갈릴 엉화
# 더 터닝	1	이 영화를 봤지만 동시에 보지 않았다고 말해도 당신은 절대 미친것이 아니다. 유령처럼 아무 실체가 없는 이런건 영화도 아니지. 감독이 유령이었거나 미쳤거나 둘 중 하나
# 다만 악에서 구하소서	5	...테이큰 인질영화 짜집기 평점낚였다
# 디어 헌터	8	결혼식 장면이 지나치게 긴 것이 흠이지만 여운이 길고 깊다
# 어느 가족	10
# 콜	10	배우들 연기 특히 전종서라는 배우 소름돋습니다..
# 이웃사촌	2	쓰레기스토리 재미도없고 감흥도 없고
# 이웃집 토토로	10	10대 초등학생인데 존잼입니다. 진짜 1988년도에 만들어졌다는게 믿기지 않을 정도.
# 콜	10	연기 대박이에요 전종서님이 원탑인듯
# 콜	8	오랜만에 괜찮은 영화네요 잼있게 잘봤어요
# 태양의 눈물	6	다소 억지스러운 스토리와 유치한 진행 이런정도의 영화라면 그것은 시간낭비
# 신의 한 수: 귀수편	2	현실성도 개연성도 없다..215만명이 본 게 신기하다.평점도 신기하다.
# 국가부도의 날	10	두번째 보는데요 개인적으로 인터스텔라급영화입니다
# 콜	10	진짜 스릴 넘쳐요 스토리도 좋아서 정말 재밌었어요 몰입감 최고
# 콜	8	연기미쳤다...진짜스릴넘치게잘봤습니다
# 소리도 없이	1	진짜 유아인 말한마디도 안하고 진짜 무슨내용을 전하고자하는지 하나도 모르겠음 노잰
# 콜	6	You don't have to call me
# 이웃사촌	8	잘 짜집기한 운동권 영화,코로나가 없었다면 그쪽 동네 사람들이훠훠훠 거리면서 페이스북에 감상평 올릴 영화
# 콜	1	배우들 연기는 진짜 좋은데 주인공이 너무 멍청함;; 고구마 천개는 먹은듯 진짜 답답
# 콜	10	정말 시나리오도 연기도 짱짱짱!!!
# 더 컨덕터	10
# 콜	10
# 콜	6	지루한 스릴러. 과거의 실수는 되돌릴 수 없다.
# 콜	10	연기,연출, 영상 뭐하나 빠지는게 없네요시간순삭재미있네요
# 콜	8	영화 콜이 흥행성공한다면 전종서님의 연기력이 99프로를 차지하지 않나 싶다. 아쉬운 점이 있다면, 타임 슬립이 매끄럽지 못하다는 점이다. 간혹 전화 한 통으로 과거가 바뀌고 미래의 공간이 바꼈지만 박신혜의 기억은 전부 돌아오지 않는 아이러니한 상황이 종종 발생했다.또한, 닫힌 결말이 아닌 열린 결말을 보여주고자하는 제작진의 압박감이었을까? 그래서인지, 영화 콜의 결말은 깔끔하지 못하고 어설프기까지 했다. 아쉬움이 남는 엔딩이었다. 어쨌든.. 전종서님의 연기력은 정말 잊지 못할 것 같다.전배우님 다음 작품이 기대된다. ^^
# 콜	10	완전 압도감 몰입도 최고보면서 점점 더 무서워지는 영화배우들 연기너무좋고 감독 연출 멋지네요글고 감독님 넘 멋져요
# 컬러 퍼플	10	내생에 최고의 감동 영화입니다 울다가 웃다가 ㅠ^^
# 아이덴티티	10	여태 봤던 스릴러 반전 영화 중 손 꼽을 정도인 영화
# 콜	10	진짜 너무무서워서 끄고싶은데 재밋어서 못끄겟고 소름돋고 아ㅠ
# 신의 한 수: 귀수편	2	혼자죽지않고싶지만...나하나로 끝내라니미 이게영화면 내가신이다
# 콜	8	초반에 좀 답답하긴 했는데 그래도 킬링타임으로 재밌게 잘 봤음 악역으로 나오시는 분 연기 잘하심 굿
# 콜	10	흠.. 간만에 수작이 나왔네요 굿잼
# 최미역행	1	양심있나?? 짱 깨 넘 들 미 쳤 네....Taiwan No.1
# 이웃사촌	2	영화 소개프로그램에서는 시종일관 유쾌할 줄 알았는데 신파극 들어가 있고 전형적인 빨갱이 좌파 어쩌고 하는 80년대 얘기. 마치 그 때 경찰이나 청와대 사람들은 악마들인것 처럼 나오고. 시대를 추억할만한 즐거운 이야기도 없다. 80년대에 소년기를 보낸 입장에서 그 시절이 암흑이지만은 않았는데 아주 뻔한 악마정권과 선한 운동권이 나온다. 지루해서 나오려다가 추워서 그냥 앉아있었다.
# 호텔 뭄바이	10
# 이별의 아침에 약속의 꽃을 장식하자	10	새벽감성진짜 개오지네
# 콜	4
# 콜	10	전종서 싸이코연기가 미쳤습니다ㄷㄷ욕하는거ㄷㄷ
# 콜	10	전종서 박신혜 이엘 김성령 연기가 너무 다 미쳤다 ..전종서씨너무 무서워요
# 런	10	이거 진짜 재미있음 정말
# 런	8
# 이웃사촌	10
# 죽지않는 인간들의 밤	7	자기 주려고 고기 삶았지~ 부분부터 겁나 웃김 특히 이미도 배우의 얼굴연기와 조울증이야 가 오버랩돼서 너무 재밌음 초반엔 재미없고 마지막도 재미없음
# 버닝	10	와.. 뭔가 해석잘하시는분이 리뷰보고싶어요! 굉장히 뭔가 내용이 있는데 어렵네요 그리고 유아인씨 정말 감탄합니다 한국배우중 최고인것같아요
# 힐빌리의 노래	2	배우들의 연기력이 아까울 정도로 평작 이자 못해 망작.넷플렉스의. 올해의 실수. 글렌클로즈와 에이미 아담스는 아카데미 여우주연수상의 기회를 놓칠 것 같다.최악의 편집과 연출로 론하워드 감독은 두 여배우의 열연을 묻어버림
# 콜	10	전종서 연기 소름ㅠㅠ마지막까지 재밌게봄
# 콜	10	진심.... 재밌게 봤습니다!  귀찮아서  안 볼려 하다가 심심해서 봤는데 소름이 쫙 도네요. 오랜만에 좋은 영화 봤어요. 교훈 : 인생은 쉽게 얻어 지는 것은 없다.
# 콜	10	너무너무 재밌게 봤어요
# 황제를 위하여	2	아 증말 !! 총체적인 난국 !! 잔인하기는 엄청 잔인함  보다가 진짜 돌아버림
# 콜	4	아우 보는내내짜증나는 영화 이딴거
# 최미역행	1	양심이라는걸 좀 가지고 살아라
# 콜	6	The Call
# 파고	10
# 도굴	10	재밌게봤어요 2도 나왔으면 좋겠네요
# 콜	4	답답 진짜 너무 답답해요 영화보는내내 답답합니다.연기는 진짜 소름돋게 잘하시고 영상미나 연출도 좋은데 주인공이 너무 답답하고 결말도 별로였습니다.
# 비커밍 제인	6	오편을 재밌게보셨다면 같이보면 흥미로운 작품이예요! 큰재미는없었던
# 최미역행	1	이거 배급하는 배급사는 머가리 터졌냐?
# 런	10	20OOO 서치에 이은 올해 최고의 영화
# 최미역행	1	거르고 나 자신을 믿는다
# 천문: 하늘에 묻는다	10	조선 왕조 역사에 세종과 장영실과 같은 인물들이 여럿 있었다면 참 좋았겠다라는 생각이 들었어요. 보면서 많이 울었습니다.
# 최미역행	1	정신 나간 놈들인가이걸 우리나라에서 개봉한다고?지들이 이 난리쳐놓고 수습하는 걸 보고 뭐감명깊게 보라 이런거임?절대 안볼거고 만약 국민보다 중국이 더 우선인 각하께서 보신다면 그거 꼭 기사로 내줘라
# 콜	10	개무섭다. 여운이 남는 영화
# 콜	10	역대급 빌런 '영숙' 전종서. 여자 조커 급 연기력. 최고 몰입감!
# 레베카	10
# 콜	10
# 콜	10	영화 끝날때까지 긴장을 늦출수 없다.
# 콜	8	간만에 한국영화 끝까지 완주햇네요.. 추천할만해요
# 프리키 데스데이	10	주인공도 너무 매력적이고 지루할 틈 없이 재밌었습니다.
# 콜	6	응답하라1988 공포버젼~ㅋㅋ
# 삼진그룹 영어토익반	10	진짜 몰입되게 하고 최고의연기력이었어요다들 재밌다고 추천하는데는 이유가 있었네요 ㅜㅠ
# 콜	7	전종서의 연기에 소름이 돋았다. 다음 영화가 기대되는 배우
# 도굴	8	킬링타임용 영화로 추천합니다 볼만해요
# 콜	9	엄마생각나서 울다가 눈물 쏙 들어갔네
# 콜	1	저는 별로에요ㅜ 스토리가 너무 뻔함
# 어벤져스: 엔드게임	10
# 극장판 바이올렛 에버가든	10	내일 세번째로 보러감 ㅇㅇ
# 콜	10	올해 본 영화중 최고 재밌음. 흡입력 짱짱! 흔한 소재인데 전개가 흥미진진하다. 강추.
# 콜	10	올해 본 영화중 최고 재밌음. 흡입력 짱짱! 흔한 소재인데 전개가 흥미진진하다. 강추.
# 콜	10	무서워... 근데 흥미진진
# 플립	10	연출, 연기, 스토리 하나 빠짐없이 너무 좋아요 진짜...강추
# 서유기 2 - 선리기연	8	쿵푸허슬, 소림축구를 재밌게 보았고 평가가 좋아서 기대를 했는데 기대가 너무 컷던 것 같다. 현시점에서 보는 옛날영화라 그런 것도 있는거 같기도하고..
# 콜	10	많이 무서워요 ㅠㅠ 저는 살짝 스킵하면서 봤어요 ㅠㅠ 가능하면 혼자 보지마세요 ㅠㅠ 그래도 스토리랑 연기력 둘 다 훌륭해요!!
# 콜	7	다시 태어난거 같다 할때 등장씬은 관상의 수양대군 등장씬의 또 다른 버전 같았다
# 삼진그룹 영어토익반	10	야! 나 좀 그만보고 너를 봐.니 인생이나 신경써.
# 콜	8	전종서. 소화기. 전화잘받자
# 콜	9	연기며 스토리며 미쳤다... 뻔하지 않은 뒷 이야기를 예측할 수 없는 반전에 반전에 반전
# 택스 콜렉터	2	ㅂㆍㅅ같은영화  20분만에 나옴 그나마 음악이 들을만했음
#
# 490
# an integer is required (got type str)

# %%
 def load_data(file_path):
    # file_path에 있는 데이터를 읽어 옴
        
    train = []

    count = 0
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f.readlines():
            
            title = ''
            score = ''
            comment = ''
            
            if count == 500:
                break
                
            line = line.strip()
            data = line.split('\t')
            
            if(len(data) < 3):
                title, score = data
            else:
                title, score, comment = data
                
            score = int(score)
            
            if score >= 9: 
                score = 'pos'
                
            else:
                score = 'neg'
                
            train.append((comment, score))
            count += 1
            
    return train

# %%
train = load_data('train.txt')
print(train[:5])
# Out:
# [('연기력,영상미, 연출, 배경음악 몰입도  네요빗나간 인간의 집착이 무모하고, 고뇌하는인간의처절한삶을 잘 묘사한듯 합니다. 아름다운영상이었어요...', 'pos'), ('전종서님 연기 진짜잘하신다..소름돋네 이분나오는거다봐야겠다배우들전체적으로 연기 다 너무잘하고어색한거하나 없음 스토리도 너무좋아시그널같아..', 'pos'), ('연출이나 무대세트들은 분위기에 맞게 잘만든거같음근데 중반부로 갈수록 이게 귀신영화인지 좀비영환지 좀 헷갈림;;하정우 애잃은 아빠같지않게 너무 태연하게 연기한거같아서 좀 아쉬웠음 그래도 감독이 뭘 전하고자 하는지는 알겠음', 'neg'), ('태어나서 처음 별점 남겨봄 빡칠때 보면 더 개빡치는 영화', 'neg'), ('몰입력짱 연기력 짱짱임', 'neg')]

# %% [markdown]
# ##  나이브 베이즈 분류기 사용해서 분석하기.

# %%
from nltk.tokenize import word_tokenize
import nltk

from konlpy.tag import Okt
okt = Okt()

def pos_tokenize(raw_sent):
    pos_sent = []    
    sent = okt.pos(raw_sent, norm=True, stem=True)    
    
    for tup in sent:        
        word, tag = tup[0], tup[1]       # tup: ('사과', 'Noun')
        word_tag = word + '/' + tag      # word_tag: '사과/Noun'
        pos_sent.append(word_tag)
    
    return ' '.join(pos_sent)

def make_word_dict(train, use_morph=False):
    all_words = set()

    for tup in train:
        sent, label = tup[0], tup[1]    
        if use_morph: sent = pos_tokenize(sent)    # pos_tokenize 함수 추가
        words = word_tokenize(sent)
        for word in words:
            all_words.add(word)

    return all_words

def make_train_feats(train, all_words, use_morph=False):
    train_features = []

    for tup in train:
        sent, label = tup[0], tup[1]
        if use_morph: sent = pos_tokenize(sent)    # pos_tokenize 함수 추가
        words = word_tokenize(sent)
        tmp = {set_word: (set_word in words) for set_word in all_words}
        sent_tup = (tmp, label)
        train_features.append(sent_tup)
    
    return train_features

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
use_morph = True
all_words = make_word_dict(train, use_morph)
print('단어 집합 개수: ', len(all_words))

train_features = make_train_feats(train, all_words, use_morph)
# Out:
# 단어 집합 개수:  2117

# %%
classifier = nltk.NaiveBayesClassifier.train(train_features)
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#           답답하다/Adjective = True              neg : pos    =     11.0 : 1.0
#            아깝다/Adjective = True              neg : pos    =     10.0 : 1.0
#                  최고/Noun = True              pos : neg    =      9.1 : 1.0
#                  과거/Noun = True              neg : pos    =      7.9 : 1.0
#                  보기/Noun = True              neg : pos    =      6.8 : 1.0
#                  이고/Josa = True              neg : pos    =      6.8 : 1.0
#                 1/Number = True              neg : pos    =      6.8 : 1.0
#                 고구마/Noun = True              neg : pos    =      6.8 : 1.0
#                 성/Suffix = True              neg : pos    =      5.8 : 1.0
#                  설정/Noun = True              neg : pos    =      5.8 : 1.0

# %%
test_sent1 = '사랑스럽고 정말 재밌었던 영화'

if use_morph: test_sent = pos_tokenize(test_sent)   # pos_tokenize 함수 추가
words = word_tokenize(test_sent1)
test_feature = {set_word: (set_word in words) for set_word in all_words}

# print(test_feature)

# %%
classifier.classify(test_feature)
# Out:
# 'pos'

# %%
test_sent2 = '세상에서 아름다운 영화'

if use_morph: test_sent = pos_tokenize(test_sent)   # pos_tokenize 함수 추가
words = word_tokenize(test_sent2)
test_feature = {set_word: (set_word in words) for set_word in all_words}

# print(test_feature)

# %%
classifier.classify(test_feature)
# Out:
# 'pos'

# %%
test_sent3 = '행복하고 아름다운 영화'

if use_morph: test_sent = pos_tokenize(test_sent)   # pos_tokenize 함수 추가
words = word_tokenize(test_sent3)
test_feature = {set_word: (set_word in words) for set_word in all_words}

# print(test_feature)

# %%
classifier.classify(test_feature)
# Out:
# 'pos'

# %% [markdown]
# # 어려운 점과 어떻게 해결했는지에 대해 서술하기.
# ### 먼저 txt 파일을 만들때  utf-8로 설정을 안하고 해서 그 부분에서 해결하는데 시간이 좀
# ### 걸려서 힘들었고, 데이터를 split하는 부분에 있어서도 expected value는 3개인데
# ### 자꾸 2개만 들어가는 문제가 발생했는데 반복문마다 type을 찍어 확인 후 전부 해결했습니다
